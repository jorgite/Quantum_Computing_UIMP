# %% [markdown]
# # Exercise 2. QUANTUM WALKS
#
# ## One-dimensional, discrete-tiem Hadarmard quantum walk. Computing probabilities...
#
# ## Jorge Giménez Tenés

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Math, display

# %%
# PARAMETERS AND INITIAL CONDITIONS

# number of time steps (iterations) --> j
jmax=10     # the exercise just ask for 3, but to have it more complete we do more
j=np.linspace(0, jmax, jmax+1)  # time steps array

# available positions in the chain
p=np.linspace(-jmax, jmax, 2*jmax+1)  # positions only from -j to j

#probabilty amplitudes
P=np.zeros((len(p), len(j)))  # probability amplitude array initialized to zero

# wave function arrays initialization
phi_up=np.zeros((len(p), len(j)), dtype=complex)  # wave function array initialized to zero
phi_down=np.zeros((len(p), len(j)), dtype=complex)  # wave function array initialized to zero
phi_up[jmax]=1/np.sqrt(2)  # initial condition: all amplitude at position 0, half spin up
phi_down[jmax]=1j/np.sqrt(2) # initial condition: all amplitude at position 0, half spin down

# %%
# EVOLUTION RULES

print("Showing only the results different from 0:")
for j in range(0, jmax-1):  # loop over time steps
   print(f"Time step j={j}:")
   for p in range(0, 2*jmax):  # loop over positions
      phi_up[p,j+1]=1/np.sqrt(2)*(phi_up[p-1,j]+phi_down[p+1,j])  # evolution rule for spin up
      phi_down[p,j+1]=1/np.sqrt(2)*(phi_up[p-1,j]-phi_down[p+1,j])  # evolution rule for spin down
      P[p, j]=np.abs(phi_up[p, j])**2+np.abs(phi_down[p, j])**2  # calculate probability amplitude
       # SHOWING RESULTS
      if phi_up[p,j] != 0:
         print(f"Position p={p-jmax}:")
         latex_str = fr"\psi_{{up}}={phi_up[p,j]:.3g}, \;\;\;\; \psi_{{down}}={phi_down[p,j]:.3g}, \;\;\;\; P={P[p,j]:.3g}"
         display(Math(latex_str))
   # plotting the probability distribution at each time step
   positions = np.arange(len(P[:, j])) - jmax
   plt.figure(figsize=(6, 3))
   plt.bar(positions, P[:, j], width=1, color='skyblue', alpha=1)
   plt.title(f'Probability Distribution, Time Step j={j}')
   plt.xlabel('Position p')
   plt.ylabel('Probability P')
   plt.xlim(-jmax, jmax)
   plt.ylim(0, 1)
   plt.grid(True, linestyle='--', alpha=0.5)
   plt.xticks(positions)  # ensures correct x-ticks
   plt.show()
   print("\n")
# Out:
# Showing only the results different from 0:
# Time step j=0:
# Position p=0:
# $\displaystyle \psi_{up}=0.707+0j, \;\;\;\; \psi_{down}=0+0.707j, \;\;\;\; P=1$
# Time step j=1:
# Position p=-1:
# $\displaystyle \psi_{up}=0+0.5j, \;\;\;\; \psi_{down}=0-0.5j, \;\;\;\; P=0.5$
# Position p=1:
# $\displaystyle \psi_{up}=0.5+0j, \;\;\;\; \psi_{down}=0.5+0j, \;\;\;\; P=0.5$
# Time step j=2:
# Position p=-2:
# $\displaystyle \psi_{up}=0-0.354j, \;\;\;\; \psi_{down}=0+0.354j, \;\;\;\; P=0.25$
# Position p=0:
# $\displaystyle \psi_{up}=0.354+0.354j, \;\;\;\; \psi_{down}=-0.354+0.354j, \;\;\;\; P=0.5$
# Position p=2:
# $\displaystyle \psi_{up}=0.354+0j, \;\;\;\; \psi_{down}=0.354+0j, \;\;\;\; P=0.25$
# Time step j=3:
# Position p=-3:
# $\displaystyle \psi_{up}=0+0.25j, \;\;\;\; \psi_{down}=0-0.25j, \;\;\;\; P=0.125$
# Position p=-1:
# $\displaystyle \psi_{up}=-0.25+0j, \;\;\;\; \psi_{down}=0.25-0.5j, \;\;\;\; P=0.375$
# Position p=1:
# $\displaystyle \psi_{up}=0.5+0.25j, \;\;\;\; \psi_{down}=0+0.25j, \;\;\;\; P=0.375$
# Position p=3:
# $\displaystyle \psi_{up}=0.25+0j, \;\;\;\; \psi_{down}=0.25+0j, \;\;\;\; P=0.125$
# Time step j=4:
# Position p=-4:
# $\displaystyle \psi_{up}=0-0.177j, \;\;\;\; \psi_{down}=0+0.177j, \;\;\;\; P=0.0625$
# Position p=-2:
# $\displaystyle \psi_{up}=0.177-0.177j, \;\;\;\; \psi_{down}=-0.177+0.53j, \;\;\;\; P=0.375$
# Position p=0:
# $\displaystyle \psi_{up}=-0.177+0.177j, \;\;\;\; \psi_{down}=-0.177-0.177j, \;\;\;\; P=0.125$
# Position p=2:
# $\displaystyle \psi_{up}=0.53+0.177j, \;\;\;\; \psi_{down}=0.177+0.177j, \;\;\;\; P=0.375$
# Position p=4:
# $\displaystyle \psi_{up}=0.177+0j, \;\;\;\; \psi_{down}=0.177+0j, \;\;\;\; P=0.0625$
# Time step j=5:
# Position p=-5:
# $\displaystyle \psi_{up}=0+0.125j, \;\;\;\; \psi_{down}=0-0.125j, \;\;\;\; P=0.0312$
# Position p=-3:
# $\displaystyle \psi_{up}=-0.125+0.25j, \;\;\;\; \psi_{down}=0.125-0.5j, \;\;\;\; P=0.344$
# Position p=-1:
# $\displaystyle \psi_{up}=0-0.25j, \;\;\;\; \psi_{down}=0.25+0j, \;\;\;\; P=0.125$
# Position p=1:
# $\displaystyle \psi_{up}=0+0.25j, \;\;\;\; \psi_{down}=-0.25+0j, \;\;\;\; P=0.125$
# Position p=3:
# $\displaystyle \psi_{up}=0.5+0.125j, \;\;\;\; \psi_{down}=0.25+0.125j, \;\;\;\; P=0.344$
# Position p=5:
# $\displaystyle \psi_{up}=0.125+0j, \;\;\;\; \psi_{down}=0.125+0j, \;\;\;\; P=0.0312$
# Time step j=6:
# Position p=-6:
# $\displaystyle \psi_{up}=0-0.0884j, \;\;\;\; \psi_{down}=0+0.0884j, \;\;\;\; P=0.0156$
# Position p=-4:
# $\displaystyle \psi_{up}=0.0884-0.265j, \;\;\;\; \psi_{down}=-0.0884+0.442j, \;\;\;\; P=0.281$
# Position p=-2:
# $\displaystyle \psi_{up}=0.0884+0.177j, \;\;\;\; \psi_{down}=-0.265+0.177j, \;\;\;\; P=0.141$
# Position p=0:
# $\displaystyle \psi_{up}=-0.177-0.177j, \;\;\;\; \psi_{down}=0.177-0.177j, \;\;\;\; P=0.125$
# Position p=2:
# $\displaystyle \psi_{up}=0.177+0.265j, \;\;\;\; \psi_{down}=-0.177+0.0884j, \;\;\;\; P=0.141$
# Position p=4:
# $\displaystyle \psi_{up}=0.442+0.0884j, \;\;\;\; \psi_{down}=0.265+0.0884j, \;\;\;\; P=0.281$
# Position p=6:
# $\displaystyle \psi_{up}=0.0884+0j, \;\;\;\; \psi_{down}=0.0884+0j, \;\;\;\; P=0.0156$
# Time step j=7:
# Position p=-7:
# $\displaystyle \psi_{up}=0+0.0625j, \;\;\;\; \psi_{down}=0-0.0625j, \;\;\;\; P=0.00781$
# Position p=-5:
# $\displaystyle \psi_{up}=-0.0625+0.25j, \;\;\;\; \psi_{down}=0.0625-0.375j, \;\;\;\; P=0.211$
# Position p=-3:
# $\displaystyle \psi_{up}=-0.125-0.0625j, \;\;\;\; \psi_{down}=0.25-0.312j, \;\;\;\; P=0.18$
# Position p=-1:
# $\displaystyle \psi_{up}=0.187+1.96e-17j, \;\;\;\; \psi_{down}=-0.0625+0.25j, \;\;\;\; P=0.102$
# Position p=1:
# $\displaystyle \psi_{up}=-0.25-0.0625j, \;\;\;\; \psi_{down}=1.96e-17-0.187j, \;\;\;\; P=0.102$
# Position p=3:
# $\displaystyle \psi_{up}=0.312+0.25j, \;\;\;\; \psi_{down}=-0.0625+0.125j, \;\;\;\; P=0.18$
# Position p=5:
# $\displaystyle \psi_{up}=0.375+0.0625j, \;\;\;\; \psi_{down}=0.25+0.0625j, \;\;\;\; P=0.211$
# Position p=7:
# $\displaystyle \psi_{up}=0.0625+0j, \;\;\;\; \psi_{down}=0.0625+0j, \;\;\;\; P=0.00781$
# Time step j=8:
# Position p=-8:
# $\displaystyle \psi_{up}=0-0.0442j, \;\;\;\; \psi_{down}=0+0.0442j, \;\;\;\; P=0.00391$
# Position p=-6:
# $\displaystyle \psi_{up}=0.0442-0.221j, \;\;\;\; \psi_{down}=-0.0442+0.309j, \;\;\;\; P=0.148$
# Position p=-4:
# $\displaystyle \psi_{up}=0.133-0.0442j, \;\;\;\; \psi_{down}=-0.221+0.398j, \;\;\;\; P=0.227$
# Position p=-2:
# $\displaystyle \psi_{up}=-0.133+0.133j, \;\;\;\; \psi_{down}=-0.0442-0.221j, \;\;\;\; P=0.0859$
# Position p=0:
# $\displaystyle \psi_{up}=0.133-0.133j, \;\;\;\; \psi_{down}=0.133+0.133j, \;\;\;\; P=0.0703$
# Position p=2:
# $\displaystyle \psi_{up}=-0.221+0.0442j, \;\;\;\; \psi_{down}=-0.133-0.133j, \;\;\;\; P=0.0859$
# Position p=4:
# $\displaystyle \psi_{up}=0.398+0.221j, \;\;\;\; \psi_{down}=0.0442+0.133j, \;\;\;\; P=0.227$
# Position p=6:
# $\displaystyle \psi_{up}=0.309+0.0442j, \;\;\;\; \psi_{down}=0.221+0.0442j, \;\;\;\; P=0.148$
# Position p=8:
# $\displaystyle \psi_{up}=0.0442+0j, \;\;\;\; \psi_{down}=0.0442+0j, \;\;\;\; P=0.00391$
